# %% [markdown]
# # Optical Interconnection Network - DNN - Regression (cleaned version)

# %% [markdown]
# ## 1. Import Libraries

# %%
# General libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data preprocessing and feature engineering
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 2. Data Preprocessing and Visualization

# %% [markdown]
# ### 2.1. Load dataframe (df)

# %%
# Load dataframe (df) into appropriate format
df = pd.read_csv('optical_interconnection_network.csv', sep=';', decimal=',')
# Remove unnamed columns identified by (;)
df = df.loc[:, ~df.columns.str.match('^Unnamed')]

# %% [markdown]
# ### 2.2. Analyze dataframe

# %%
df
# Out:
#      Node Number  Thread Number  ... Network Response Time Channel Utilization
# 0             64              4  ...            700.514102            0.352431
# 1             64              4  ...            864.599227            0.506302
# 2             64              4  ...            839.372851            0.638516
# 3             64              4  ...           1256.053108            0.767051
# 4             64              4  ...           1343.875577            0.807812
# ..           ...            ...  ...                   ...                 ...
# 635           16             10  ...           1214.057768            0.961042
# 636           16             10  ...           1653.736882            0.981944
# 637           16             10  ...           1421.304936            0.962500
# 638           16             10  ...           2371.043062            0.979375
# 639           16             10  ...           2592.966463            0.980903
#
# [640 rows x 10 columns]

# %% [markdown]
# #### Spatial Distribution:
#
# - UN: Uniform
# - HR: Hot Region
# - BR: Bit Reverse
# - PS: Perfect Shuffle

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Node Number             640 non-null    int64
#  1   Thread Number           640 non-null    int64
#  2   Spatial Distribution    640 non-null    object
#  3   Temporal Distribution   640 non-null    object
#  4   T/R                     640 non-null    float64
#  5   Processor Utilization   640 non-null    float64
#  6   Channel Waiting Time    640 non-null    float64
#  7   Input Waiting Time      640 non-null    float64
#  8   Network Response Time   640 non-null    float64
#  9   Channel Utilization     640 non-null    float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 50.1+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Node Number               0
# Thread Number             0
# Spatial Distribution      0
# Temporal Distribution     0
# T/R                       0
# Processor Utilization     0
# Channel Waiting Time      0
# Input Waiting Time        0
# Network Response Time     0
# Channel Utilization       0
# dtype: int64

# %%
df.describe()
# Out:
#        Node Number  Thread Number  ...  Network Response Time  Channel Utilization
# count   640.000000     640.000000  ...             640.000000           640.000000
# mean     40.000000       7.000000  ...            1504.247529            26.347886
# std      24.018772       2.237817  ...            1202.606968           223.782214
# min      16.000000       4.000000  ...               0.529210             0.136979
# 25%      16.000000       5.500000  ...             580.676198             0.587539
# 50%      40.000000       7.000000  ...            1232.150369             0.773611
# 75%      64.000000       8.500000  ...            2115.326618             0.905573
# max      64.000000      10.000000  ...            6065.736672          2895.323131
#
# [8 rows x 8 columns]

# %% [markdown]
# ### 2.3. Clean data

# %%
# Sort dataframe according to Channel Utilization
df_sorted = df.sort_values(by=['Channel Utilization'])

# %%
df_sorted.tail(15)
# Out:
#      Node Number  Thread Number  ... Network Response Time Channel Utilization
# 159           64             10  ...           5919.152636            0.980382
# 639           16             10  ...           2592.966463            0.980903
# 636           16             10  ...           1653.736882            0.981944
# 477           16             10  ...           2980.861045            0.982778
# 478           16             10  ...           3372.189353            0.990312
# 120           64              4  ...              0.529210          607.869882
# 121           64              4  ...              0.633802          902.966929
# 122           64              4  ...              0.718047         1042.409722
# 124           64              4  ...              0.822266         1202.936709
# 123           64              4  ...              0.778299         1219.612435
# 125           64              4  ...              0.846927         1688.953232
# 126           64              4  ...              0.840790         1904.053095
# 127           64              4  ...              0.857222         2191.738331
# 128           64              4  ...              0.860000         2752.001151
# 129           64              4  ...              0.865191         2895.323131
#
# [15 rows x 10 columns]

# %%
# Remove last 10 rows of sorted dataframe
df_sorted.drop(df_sorted.tail(10).index, inplace=True)

# %%
df_sorted
# Out:
#      Node Number  Thread Number  ... Network Response Time Channel Utilization
# 560           16              4  ...             19.110126            0.136979
# 240           64              4  ...             26.502746            0.137726
# 570           16              6  ...             19.484081            0.149965
# 250           64              6  ...             21.445301            0.151797
# 580           16              8  ...             18.983249            0.153542
# ..           ...            ...  ...                   ...                 ...
# 159           64             10  ...           5919.152636            0.980382
# 639           16             10  ...           2592.966463            0.980903
# 636           16             10  ...           1653.736882            0.981944
# 477           16             10  ...           2980.861045            0.982778
# 478           16             10  ...           3372.189353            0.990312
#
# [630 rows x 10 columns]

# %%
df_sorted.describe()
# Out:
#        Node Number  Thread Number  ...  Network Response Time  Channel Utilization
# count   630.000000     630.000000  ...             630.000000           630.000000
# mean     39.619048       7.047619  ...            1528.112170             0.721877
# std      24.016044       2.223080  ...            1196.975056             0.203917
# min      16.000000       4.000000  ...              18.983249             0.136979
# 25%      16.000000       6.000000  ...             610.232346             0.585052
# 50%      16.000000       8.000000  ...            1263.970861             0.769844
# 75%      64.000000      10.000000  ...            2125.945976             0.901231
# max      64.000000      10.000000  ...            6065.736672             0.990312
#
# [8 rows x 8 columns]

# %%
# Get values for matrix of features (X) and dependent variable (y)
X, y = df_sorted.iloc[:, :-1].values, df_sorted.iloc[:, -1].values

print(X.shape, y.shape)
# Out:
# (630, 9) (630,)

# %% [markdown]
# ### 2.4. Visualize data

# %% [markdown]
# #### Pairwise relationships between features

# %%
# Pairwise distributions
sns.pairplot(df_sorted)
plt.show()

# %% [markdown]
# #### Channel Utilization per Spatial Distribution

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Channel Utilization'], 
            hue=df_sorted['Temporal Distribution'], ci=None)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Channel Utilization', fontsize=12)
plt.title('Channel Utilization per Spatial Distribution', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Channel Utilization'], 
            hue=df_sorted['Temporal Distribution'])
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Channel Utilization', fontsize=12)
plt.title('Channel Utilization per Spatial Distribution', fontsize=14)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### Channel Waiting Time per Spatial Distribution

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Channel Waiting Time'], 
            hue=df_sorted['Temporal Distribution'], ci=None)
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Channel Waiting Time (ms)', fontsize=12)
plt.title('Channel Waiting Time per Spatial Distribution', fontsize=14)
plt.legend(loc='lower right')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Channel Waiting Time'], 
            hue=df_sorted['Temporal Distribution'])
plt.yticks(np.arange(0, 2000, 200))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Channel Waiting Time (ms)', fontsize=12)
plt.title('Channel Waiting Time per Spatial Distribution', fontsize=14)
plt.show()

# %% [markdown]
# #### Processor Utilization per Spatial Distribution

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Processor Utilization '], 
            hue=df_sorted['Temporal Distribution'], ci=None)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Processor Utilization', fontsize=12)
plt.title('Processor Utilization per Spatial Distribution', fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Processor Utilization '], 
            hue=df_sorted['Temporal Distribution'])
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Processor Utilization', fontsize=12)
plt.title('Processor Utilization per Spatial Distribution', fontsize=14)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### Network Response Time per Spatial Distribution

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Network Response Time'], 
            hue=df_sorted['Temporal Distribution'], ci=None)
plt.yticks(np.arange(0, 3500, 500))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Network Response Time (ms)', fontsize=12)
plt.title('Network Response Time per Spatial Distribution', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Network Response Time'], 
            hue=df_sorted['Temporal Distribution'])
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Network Response Time (ms)', fontsize=12)
plt.title('Network Response Time per Spatial Distribution', fontsize=14)
plt.show()

# %% [markdown]
# #### Input Waiting Time per Spatial Distribution

# %%
plt.figure(figsize=(8,8))
sns.barplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Input Waiting Time'], 
            hue=df_sorted['Temporal Distribution'], ci=None)
plt.yticks(np.arange(0, 450, 50))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Input Waiting Time (ms)', fontsize=12)
plt.title('Input Waiting Time per Spatial Distribution', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df_sorted['Spatial Distribution'], y=df_sorted['Input Waiting Time'], 
            hue=df_sorted['Temporal Distribution'])
plt.yticks(np.arange(0, 1200, 200))
plt.xlabel('Spatial Distribution', fontsize=12)
plt.ylabel('Input Waiting Time (ms)', fontsize=12)
plt.title('Input Waiting Time per Spatial Distribution', fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### Correlation Map

# %%
# Correlation Map
plt.figure(figsize=(10,10))
sns.heatmap(df_sorted.corr(), cmap='bwr', annot=True, fmt = ".2f")
plt.xticks(rotation=50)
plt.yticks(rotation=0)
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# ### 2.5. Feature Engineering

# %%
# Label Encode the Spatial Distribution column
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])
# X[:, 3] = le.fit_transform(X[:, 3])

# %%
# One-Hot Encode the Temporal Distribution column
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
X[:5, :]
# Out:
# array([[1.0, 0.0, 16, 4, 0, 0.1, 0.44250100000000003, 1.013195,
#         381.61555400000003, 19.110126],
#        [1.0, 0.0, 64, 4, 0, 0.1, 0.590286, 1.474199, 313.118038,
#         26.502746000000002],
#        [1.0, 0.0, 16, 6, 0, 0.1, 0.487785, 1.1196959999999998,
#         498.820922, 19.484081],
#        [1.0, 0.0, 64, 6, 0, 0.1, 0.6481180000000001, 1.745482, 501.62453,
#         21.445301],
#        [1.0, 0.0, 16, 8, 0, 0.1, 0.5089090000000001, 1.3484180000000001,
#         652.238802, 18.983249]], dtype=object)

# %%
# Split dataframe (df) into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    random_state=0)

# %%
# Feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## 3. Define DNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define model
reg = Sequential()

# Add layers
reg.add(Dense(units=80, activation='relu', input_dim=X.shape[1]))
reg.add(Dense(units=80, activation='relu'))
reg.add(Dense(units=60, activation='relu'))
reg.add(Dropout(0.02))

reg.add(Dense(units=1))

# Compile model
reg.compile(optimizer='adam', loss='mse')

# Summarize model
reg.summary()

# Train model
history = reg.fit(X_train, y_train, batch_size=32, epochs=100, 
                  validation_data=(X_test, y_test))

# Plot loss during training
plt.plot(history.history['loss'], 'g', label='train')
plt.plot(history.history['val_loss'], 'b', label='test')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                880
#
#  dense_1 (Dense)             (None, 80)                6480
#
#  dense_2 (Dense)             (None, 60)                4860
#
#  dropout (Dropout)           (None, 60)                0
#
#  dense_3 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 12,281
# Trainable params: 12,281
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 1s 13ms/step - loss: 0.2521 - val_loss: 0.1381
# Epoch 2/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0653 - val_loss: 0.0498
# Epoch 3/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0356 - val_loss: 0.0342
# Epoch 4/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0232 - val_loss: 0.0233
# Epoch 5/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0170 - val_loss: 0.0161
# Epoch 6/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 7/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 8/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 9/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 10/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 12/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 13/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 14/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 15/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 16/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 17/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 18/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 19/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 20/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 21/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 22/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 23/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 24/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 25/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 26/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 27/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 28/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 29/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 30/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 31/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 33/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 34/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 35/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 37/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 38/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 39/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 40/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 42/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 43/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 44/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 45/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 46/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 47/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 48/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 49/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 50/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 51/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 52/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 53/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 54/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 55/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 56/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 57/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 58/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 59/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 60/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 9.9462e-04
# Epoch 61/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 9.9252e-04
# Epoch 62/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 8.9859e-04
# Epoch 63/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 64/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 65/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 66/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 67/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 68/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 69/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 70/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 71/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 72/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 73/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 9.9600e-04
# Epoch 74/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 75/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 76/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 77/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 9.4959e-04
# Epoch 79/100
# 16/16 [==============================] - 0s 3ms/step - loss: 9.9756e-04 - val_loss: 9.7385e-04
# Epoch 80/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 81/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 82/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 83/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 84/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 85/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 86/100
# 16/16 [==============================] - 0s 3ms/step - loss: 9.8272e-04 - val_loss: 0.0011
# Epoch 87/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 88/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 89/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 8.5846e-04
# Epoch 90/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 91/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.8945e-04 - val_loss: 9.5721e-04
# Epoch 92/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 93/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 94/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 95/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 96/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 97/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 98/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 99/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 100/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0013

# %% [markdown]
# ## 4. Evaluate DNN Model

# %%
# Predict test set results
y_pred = reg.predict(X_test)

# Summarize results
print('MAE: %.3f' % (mean_absolute_error(y_test, y_pred)))
print('MSE: %.3f' % (mean_squared_error(y_test, y_pred)))
print('RMSE: %.3f' % (mean_squared_error(y_test, y_pred, squared=False)))
print('R^2 Score: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# MAE: 0.027
# MSE: 0.001
# RMSE: 0.036
# R^2 Score: 0.970

# %%
# Plot histogram for y_pred
fig1 = plt.figure(figsize=(15, 6))
ax1 = fig1.add_subplot(1, 2, 1)
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 100, 10))
plt.hist(x=y_pred, facecolor='blue', alpha=0.4, edgecolor='black')
plt.xlabel('Channel Utilization', fontsize=12)
plt.ylabel('Number of Measurements', fontsize=12)
plt.title('Predicted Channel Utilization', fontsize=14)

# Plot histogram for y_test
ax1 = fig1.add_subplot(1, 2, 2)
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 100, 10))
plt.hist(x=y_test, facecolor='orange', alpha=0.6, edgecolor='black')
plt.xlabel('Channel Utilization', fontsize=12)
plt.ylabel('Number of Measurements', fontsize=12)
plt.title('Validation Channel Utilization', fontsize=14)

# Show subplot
plt.show()

# %% [markdown]
# ## 5. Sample Results

# %% [markdown]
# <table border = "1">
#   <thead>
#     <th colspan = "3">Sample Neural Network Regression Scores</th>
#   </thead>
#     <tr>
#       <td><b>MAE</b></td>
#       <td>0.027</td>
#     </tr>
#     <tr>
#       <td><b>MSE</b></td>
#       <td>0.001</td>
#     </tr>
#     <tr>
#       <td><b>RMSE</b></td>
#       <td>0.036</td>
#     </tr>
#     <tr>
#       <td><b>R^2</b></td>
#       <td>0.970</td>
#     </tr>
#   </tbody>
# </table>
#
# Note: These results will vary due to the random nature of Deep Learning.

# %% [markdown]
# ## 6. Remarks

# %% [markdown]
# *   Removing those 10 outliers ensures that the results obtained are more consistent.
# *   Given that the original dataset contained 640 samples, removing 10 of them does not significantly affect the remaining data present nor the ability of the Deep Learning model used to make accurate predictions.
#
# **Suggested Improvements:**
#
# - Consider experimenting with additional dropout regularization.
# - Try increasing/decreasing the amount of layers used or neurons per layer.
